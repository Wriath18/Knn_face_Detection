# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\sanid\appdata\local\programs\python\python310\lib\site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\sanid\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (1.23.5)
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2

# %%
img = cv2.imread("../kitten.jpg")
gray = cv2.imread("../kitten.jpg", cv2.IMREAD_GRAYSCALE)

# %%
cv2.imshow('image',img)
cv2.imshow('gray',gray)
#Wait for any key before image disappears
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread("../kitten.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)#

# %%
plt.imshow(img)

# %% [markdown]
# Video Stream

# %%
cam = cv2.VideoCapture(0)
while True:
    ret_value, frame = cam.read()
    if ret_value == False:
        continue
    cv2.imshow("Video Capture",frame)

    key_pressed = cv2.waitKey(1) & 0xFF
    if key_pressed == ord("s"):
        break

cam.release()
cv2.destroyAllWindows()

# %%
cam = cv2.VideoCapture(0)
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")


while True:
    ret_value, frame = cam.read()
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    if ret_value == False:
        continue
    faces = face_cascade.detectMultiScale(gray_frame,1.3,5)


    for (x,y,w,h) in faces:
        cv2.rectangle(frame, (x,y), (x+w, y+h), (245,255,0),2)

    cv2.imshow("Video Frame", frame)

    key_pressed = cv2.waitKey(1) & 0xFF
    if key_pressed == ord("s"):
        break

cam.release()
cv2.destroyAllWindows()
